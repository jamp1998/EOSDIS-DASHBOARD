# %%
#DATA WRANGALING OF DATASET  EOSDIS MISSION

# %%
# Importing libraries 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
#Importing raw data
data = pd.read_csv('1900_2021_DISASTERS.csv')

# %%
#Exploring dataset

# %%
print(data.head())
# Out:
#    Year   Seq Glide Disaster Group Disaster Subgroup      Disaster Type  \
# 0  1900  9002   NaN        Natural    Climatological            Drought
# 1  1900  9001   NaN        Natural    Climatological            Drought
# 2  1902    12   NaN        Natural       Geophysical         Earthquake
# 3  1902     3   NaN        Natural       Geophysical  Volcanic activity
# 4  1902    10   NaN        Natural       Geophysical  Volcanic activity
#
#   Disaster Subtype Disaster Subsubtype   Event Name     Country  ...  \
# 0          Drought                 NaN          NaN  Cabo Verde  ...
# 1          Drought                 NaN          NaN       India  ...
# 2  Ground movement                 NaN          NaN   Guatemala  ...
# 3         Ash fall                 NaN  Santa Maria   Guatemala  ...
# 4         Ash fall                 NaN  Santa Maria   Guatemala  ...
#
#   No Affected No Homeless Total Affected Insured Damages ('000 US$)  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16126 entries, 0 to 16125
# Data columns (total 45 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        16126 non-null  int64
#  1   Seq                         16126 non-null  int64
#  2   Glide                       1581 non-null   object
#  3   Disaster Group              16126 non-null  object
#  4   Disaster Subgroup           16126 non-null  object
#  5   Disaster Type               16126 non-null  object
#  6   Disaster Subtype            13016 non-null  object
#  7   Disaster Subsubtype         1077 non-null   object
#  8   Event Name                  3861 non-null   object
#  9   Country                     16126 non-null  object
#  10  ISO                         16126 non-null  object
#  11  Region                      16126 non-null  object
#  12  Continent                   16126 non-null  object
# ...

# %%
#Checking missing data 
print(data.isnull())
# Out:
#         Year    Seq  Glide  Disaster Group  Disaster Subgroup  Disaster Type  \
# 0      False  False   True           False              False          False
# 1      False  False   True           False              False          False
# 2      False  False   True           False              False          False
# 3      False  False   True           False              False          False
# 4      False  False   True           False              False          False
# ...      ...    ...    ...             ...                ...            ...
# 16121  False  False  False           False              False          False
# 16122  False  False   True           False              False          False
# 16123  False  False  False           False              False          False
# 16124  False  False   True           False              False          False
# 16125  False  False   True           False              False          False
#
# ...

# %%
print(data.isnull().any())
# Out:
# Year                          False
# Seq                           False
# Glide                          True
# Disaster Group                False
# Disaster Subgroup             False
# Disaster Type                 False
# Disaster Subtype               True
# Disaster Subsubtype            True
# Event Name                     True
# Country                       False
# ISO                           False
# Region                        False
# Continent                     False
# Location                       True
# Origin                         True
# Associated Dis                 True
# Associated Dis2                True
# OFDA Response                  True
# Appeal                         True
# Declaration                    True
# Aid Contribution               True
# Dis Mag Value                  True
# Dis Mag Scale                  True
# Latitude                       True
# Longitude                      True
# Local Time                     True
# ...

# %%
print(data.isnull().sum())
# Out:
# Year                              0
# Seq                               0
# Glide                         14545
# Disaster Group                    0
# Disaster Subgroup                 0
# Disaster Type                     0
# Disaster Subtype               3110
# Disaster Subsubtype           15049
# Event Name                    12265
# Country                           0
# ISO                               0
# Region                            0
# Continent                         0
# Location                       1792
# Origin                        12332
# Associated Dis                12778
# Associated Dis2               15419
# OFDA Response                 14432
# Appeal                        13557
# Declaration                   12870
# Aid Contribution              15449
# Dis Mag Value                 11180
# Dis Mag Scale                  1190
# Latitude                      13397
# Longitude                     13394
# Local Time                    15023
# ...

# %%
print(data.count())
# Out:
# Year                          16126
# Seq                           16126
# Glide                          1581
# Disaster Group                16126
# Disaster Subgroup             16126
# Disaster Type                 16126
# Disaster Subtype              13016
# Disaster Subsubtype            1077
# Event Name                     3861
# Country                       16126
# ISO                           16126
# Region                        16126
# Continent                     16126
# Location                      14334
# Origin                         3794
# Associated Dis                 3348
# Associated Dis2                 707
# OFDA Response                  1694
# Appeal                         2569
# Declaration                    3256
# Aid Contribution                677
# Dis Mag Value                  4946
# Dis Mag Scale                 14936
# Latitude                       2729
# Longitude                      2732
# Local Time                     1103
# ...

# %%
data.describe()
# Out:
#                Year           Seq  Aid Contribution  Dis Mag Value  \
# count  16126.000000  16126.000000      6.770000e+02   4.946000e+03
# mean    1996.764790    714.784820      1.254136e+05   4.735038e+04
# std       20.159065   1929.635089      2.997875e+06   3.094242e+05
# min     1900.000000      1.000000      1.000000e+00  -5.700000e+01
# 25%     1989.000000     93.000000      1.750000e+02   7.000000e+00
# 50%     2001.000000    270.000000      7.210000e+02   1.515000e+02
# 75%     2011.000000    486.000000      3.511000e+03   1.129650e+04
# max     2021.000000   9881.000000      7.800000e+07   1.302587e+07
#
#         Start Year   Start Month     Start Day      End Year     End Month  \
# count  16126.00000  15739.000000  12498.000000  16126.000000  15418.000000
# mean    1996.77837      6.444374     15.233957   1996.835607      6.576728
# std       20.15571      3.393965      8.953821     20.143010      3.352965
# ...

# %%
print(data.shape)
# Out:
# (16126, 20)

# %%
#Data cleaning

# %%
#Drop columns that are not necessary for the project 
data.drop(['Glide', 'Disaster Subsubtype', 'Start Year', 'Start Month', 'Start Day', 'End Year', 'End Month', 'End Day', 'Total Deaths',])

# %%
data.drop(['Insured Damages ('000 US$')', 'Total Damages('000 US$')'], axis=1)
# Out:
#   Input In [93]
#     data.drop(['Insured Damages ('000 US$')', 'Total Damages('000 US$')'], axis=1)
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#Rename the columns for special characthers 
data.rename(columns={"Insured Damages ('000 US$)":"Insured Damages"}, inplace=True)
data.rename(columns={"Total Damages ('000 US$)":"Total Damages"}, inplace=True)

# %%
#Checking the change in the names of the columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16126 entries, 0 to 16125
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               16126 non-null  int64
#  1   Disaster Group     16126 non-null  object
#  2   Disaster Subgroup  16126 non-null  object
#  3   Disaster Type      16126 non-null  object
#  4   Disaster Subtype   13016 non-null  object
#  5   Country            16126 non-null  object
#  6   ISO                16126 non-null  object
#  7   Region             16126 non-null  object
#  8   Continent          16126 non-null  object
#  9   Insured Damages    1096 non-null   float64
#  10  Total Damages      5245 non-null   float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 1.4+ MB

# %%
#Drop the last tables
data.drop(['Insured Damages', 'Total Damages'], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16126 entries, 0 to 16125
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               16126 non-null  int64
#  1   Disaster Group     16126 non-null  object
#  2   Disaster Subgroup  16126 non-null  object
#  3   Disaster Type      16126 non-null  object
#  4   Disaster Subtype   13016 non-null  object
#  5   Country            16126 non-null  object
#  6   ISO                16126 non-null  object
#  7   Region             16126 non-null  object
#  8   Continent          16126 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 1.1+ MB

# %%
# Checking the dataset 
df.isnull().sum()
# Out:
# Year                 0
# Disaster Group       0
# ISO                  0
# Disaster Subgroup    0
# dtype: int64

# %%
#Export dataset clean for analysis

# %%
data.to_csv(index=False)
# Out:
# 'Year,Disaster Group,Disaster Subgroup,Disaster Type,Disaster Subtype,Country,ISO,Region,Continent\r\n1900,Natural,Climatological,Drought,Drought,Cabo Verde,CPV,Western Africa,Africa\r\n1900,Natural,Climatological,Drought,Drought,India,IND,Southern Asia,Asia\r\n1902,Natural,Geophysical,Earthquake,Ground movement,Guatemala,GTM,Central America,Americas\r\n1902,Natural,Geophysical,Volcanic activity,Ash fall,Guatemala,GTM,Central America,Americas\r\n1902,Natural,Geophysical,Volcanic activity,Ash fall,Guatemala,GTM,Central America,Americas\r\n1903,Natural,Geophysical,Mass movement (dry),Rockfall,Canada,CAN,Northern America,Americas\r\n1903,Natural,Geophysical,Volcanic activity,Ash fall,Comoros (the),COM,Eastern Africa,Africa\r\n1904,Natural,Meteorological,Storm,Tropical cyclone,Bangladesh,BGD,Southern Asia,Asia\r\n1905,Natural,Geophysical,Mass movement (dry),Rockfall,Canada,CAN,Northern America,Americas\r\n1905,Natural,Geophysical,Earthquake,Ground movement,India,IND,Southern Asia,Asia\r\
# ...

# %%
compression_opts = dict(method='zip',
                        archive_name='out.csv')  
data.to_csv('out.zip', index=False,
          compression=compression_opts)

# %%
import os  
os.getcwd()
# Out:
# 'C:\\data_analysis\\data_envs\\Disaster_Dashboard'

# %%
os.makedirs('C:\\data_analysis\\data_envs\\Disaster_Dashboard', exist_ok=True)  
data.to_csv('C:\\data_analysis\\data_envs\\Disaster_Dashboard/out.csv')
